# %% [markdown]
# # Module 1 Project

# %% [markdown]
# Flatiron School Data Science immersive January 28 Cohort

# %% [markdown]
# This project asks to collect data either through API calls or webscraping, put them in tabular format, and create visualizations and exploratory analysis to tell a story of these data.

# %% [markdown]
# Karen Lin and Derrick Lewis collaborated on this project to collect data regarding Vegan vs. Steak Restaurants from 10 cities in the United States. The goal was to look for comparisons between these nearly opposite foods. We will look for restaturant density, price disparity and local sentiment through ratings.

# %% [markdown]
# To begin we will import data from the Yelp API.

# %% [markdown]
# This process will require several python libraries. The first "requests" will allow us to the "get" function which will organize the url, paramaters and identification key to our digital request. Next is Pandas to create DataFrames to orgnaize the data. We'll use math to create a special version of round which rounds up to the nearest integer. Lastly, we import OS to pull our API Key from our profile instead of saving it to this code.

# %%
import requests
import pandas as pd
import math
import os

# %% [markdown]
# ## The Function to pull from the API

# %% [markdown]
# Next we will build our request function. The restrictions on the Yelp API will limit our results to just 50 businesses. As most urban areas have more restaurants available we will need to create a loop to make multiple requests each time at a new starting point in the list.

# %% [markdown]
# ### Criteria

# %% [markdown]
# With some early tests directly on the Yelp website, we found more distinct results from a category search rather than searching for term across the entire data set. This returns restaurants with specific tags for that category.

# %% [markdown]
# ### Area

# %% [markdown]
# To create a uniform comparison we decided to look at an exact 40 km radius starting from each urban center. We will pair this with population date from [Freemaptools.com](https://www.freemaptools.com/find-population.htm). Which creates population estimates of a specific radius from a starting point.

# %%
client_id = os.environ.get('YELP_ID')
api_key = os.environ.get('YELP_KEY')

url = 'https://api.yelp.com/v3/businesses/search'
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }


def yelp_pull(cat, lat, lon):
    '''explain this:
    INPUTS: 
    OUTPUTS: returns a list of dictionaries for each restaurant 
    '''
    #do an initial request to get the total availble results.
    results = 0
    offset = 0
    url_params = {
                     'term': 'restaurants',
                     'limit': 50,
                     'categories': str(cat),
                     'offset': offset,
                     'latitude':lat,
                     'longitude':lon,
                     'radius':40000
                      }      
    response = requests.get(url, headers=headers, params=url_params)
    results = response.json()['total']
    
    
    temp_list= []
    rng = math.ceil(results/50)
    print(rng)
    for i in range(0,rng):
        print(offset)
        url_params = {
                     'term': 'restaurants',
                     'limit': 50,
                     'categories': str(cat),
                     'offset': offset,
                     'latitude':lat,
                     'longitude':lon,
                     'radius':40000
                      }
        
        
        response = requests.get(url, headers=headers, params=url_params)
        results = response.json()['total']
        for x in range(len(response.json()['businesses'])):
                 temp_list.append(response.json()['businesses'][x])
        offset +=50
    return temp_list

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# Step 1: Pull in the list of dictionaries specific to the city and type of food.

# %%
chi_stk_list = yelp_pull('steak', start_point['chicago'][0], start_point['chicago'][1])
# Out:
# 2
# 0
# 50

# %%
chi_stk_list
# Out:
# [{'id': 'Nk4H9CkU8B1VPAofaB2qcQ',
#   'alias': 'mables-table-chicago',
#   'name': "Mable's Table",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zk7nA0bYl0jlpuNAFQo4PQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mables-table-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 209,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.91582, 'longitude': -87.6699},
#   'transactions': ['pickup', 'restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '1655 W Cortland St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60622',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1655 W Cortland St', 'Chicago, IL 60622']},
#   'phone': '+17739047433',
#   'display_phone': '(773) 904-7433',
#   'distance': 1352.325855632121},
#  {'id': 'VPJk-SEWSWS_nGoQvM-COw',
#   'alias': 'penumbra-chicago',
#   'name': 'Penumbra',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yUkNNWqn5YVGNf7O5ySSbw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/penumbra-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 376,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 41.92445, 'longitude': -87.710933},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '3309 W Fullerton Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60647',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['3309 W Fullerton Ave', 'Chicago, IL 60647']},
#   'phone': '+17737722343',
#   'display_phone': '(773) 772-2343',
#   'distance': 3483.288177350077},
#  {'id': 'UKs05XWhbP0riI8O0Kv36w',
#   'alias': 'boeufhaus-chicago',
#   'name': 'Boeufhaus',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gW3F6I-Uf9b13d_PR8mlPg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boeufhaus-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 333,
#   'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.899831, 'longitude': -87.687487},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '1012 N Western Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60622',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1012 N Western Ave', 'Chicago, IL 60622']},
#   'phone': '+17736612116',
#   'display_phone': '(773) 661-2116',
#   'distance': 999.207192127185},
#  {'id': 'ZbXgwfVDjb2tz08FGWmSAA',
#   'alias': 'folklore-argentine-grill-chicago',
#   'name': 'Folklore Argentine Grill',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/unz_S-YuqyvmPJch7nGNxQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/folklore-argentine-grill-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 632,
#   'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.9034461975098,
#    'longitude': -87.6799240112305},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2100 W Division St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60622',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2100 W Division St', 'Chicago, IL 60622']},
#   'phone': '+17732921600',
#   'display_phone': '(773) 292-1600',
#   'distance': 268.69608457215384},
#  {'id': 'mKm2FpWxwfTayoRq9wleTA',
#   'alias': 'bobbys-lincoln-park-chicago',
#   'name': "Bobby's Lincoln Park",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-lonTRqiItdhfgqU4qlBog/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bobbys-lincoln-park-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 26,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 41.92746, 'longitude': -87.65206},
#   'transactions': [],
#   'location': {'address1': '2518 N Lincoln Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60657',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2518 N Lincoln Ave', 'Chicago, IL 60657']},
#   'phone': '+17737998555',
#   'display_phone': '(773) 799-8555',
#   'distance': 3278.2090958360996},
#  {'id': 'apyIymDFbUK7u-Y3V5kmkA',
#   'alias': 'bavettes-bar-and-boeuf-chicago',
#   'name': "Bavette's Bar & Boeuf",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UchBxzwVjn_XJ-c8xj2_9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bavettes-bar-and-boeuf-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 2094,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.8892796234574,
#    'longitude': -87.6348227262497},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '218 W Kinzie St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['218 W Kinzie St', 'Chicago, IL 60654']},
#   'phone': '+13126248154',
#   'display_phone': '(312) 624-8154',
#   'distance': 3968.647508362347},
#  {'id': 'UK5Xb8xqUOUBi5vQu0bQXQ',
#   'alias': 'maple-and-ash-chicago',
#   'name': 'Maple & Ash',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lTS4wOdEd_fPMZO08Y4c_Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/maple-and-ash-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 1009,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.9021130633339,
#    'longitude': -87.6286945502972},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '8 W Maple St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60610',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['8 W Maple St', 'Chicago, IL 60610']},
#   'phone': '+13129448888',
#   'display_phone': '(312) 944-8888',
#   'distance': 4075.1072303294945},
#  {'id': '8-9AwlQ7miS8f4dYpSr7QQ',
#   'alias': 'about-last-knife-chicago',
#   'name': 'About Last Knife',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RjOlcNdIEwST5ztih9JaOQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/about-last-knife-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 54,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8851299, 'longitude': -87.62497},
#   'transactions': [],
#   'location': {'address1': '168 N Michigan Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60601',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['168 N Michigan Ave', 'Chicago, IL 60601']},
#   'phone': '+13123922440',
#   'display_phone': '(312) 392-2440',
#   'distance': 4905.235186530093},
#  {'id': 'sNQglz_HoXgnUi1KTN3Iew',
#   'alias': 'gibsons-bar-and-steakhouse-chicago',
#   'name': 'Gibsons Bar & Steakhouse',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HfAuCT3Rq_PmgAhNEeuF3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gibsons-bar-and-steakhouse-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 1753,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.901374, 'longitude': -87.627962},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '1028 N Rush St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1028 N Rush St', 'Chicago, IL 60611']},
#   'phone': '+13122668999',
#   'display_phone': '(312) 266-8999',
#   'distance': 4143.089889122835},
#  {'id': '2tKMs0DbdxPSl2JeCJUEKw',
#   'alias': 'joes-seafood-prime-steak-and-stone-crab-chicago',
#   'name': "Joe's Seafood, Prime Steak & Stone Crab",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FPYafanrI1GVRAhtgZ8Oow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-seafood-prime-steak-and-stone-crab-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 2226,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.8918195, 'longitude': -87.6261787},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '60 E Grand Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['60 E Grand Ave', 'Chicago, IL 60611']},
#   'phone': '+13123795637',
#   'display_phone': '(312) 379-5637',
#   'distance': 4553.711534569594},
#  {'id': 'kJjbElns3_GTNIklRVbHPQ',
#   'alias': 'remingtons-chicago',
#   'name': "Remington's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HPojvEuzjb-iarCOJYvdkw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/remingtons-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 476,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.88266, 'longitude': -87.62499},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '20 N Michigan Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60602',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['20 N Michigan Ave', 'Chicago, IL 60602']},
#   'phone': '+13127826000',
#   'display_phone': '(312) 782-6000',
#   'distance': 5037.820264636369},
#  {'id': '3Q_N0K28SRJbPy2sz0QqVw',
#   'alias': 'prime-and-provisions-chicago-4',
#   'name': 'Prime & Provisions',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QkQqY6It4Clyxk9XubzVXw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prime-and-provisions-chicago-4?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 922,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.8866316388428,
#    'longitude': -87.6328291859281},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '222 N La Salle St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60601',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['222 N La Salle St', 'Chicago, IL 60601']},
#   'phone': '+13127267777',
#   'display_phone': '(312) 726-7777',
#   'distance': 4251.747195716553},
#  {'id': 'p9TVco6JdcBxt_c_TtPcgw',
#   'alias': 'swift-and-sons-chicago',
#   'name': 'Swift & Sons',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mwg713z0KaH4wB1Uxzfz6A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/swift-and-sons-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 533,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8869073066802,
#    'longitude': -87.6525044962951},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '1000 W Fulton Market',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1000 W Fulton Market', 'Chicago, IL 60607']},
#   'phone': '+13127339420',
#   'display_phone': '(312) 733-9420',
#   'distance': 2913.808639450122},
#  {'id': '43rd1LKcZRIunySzbMsyLQ',
#   'alias': 'fogo-de-chão-brazilian-steakhouse-chicago-4',
#   'name': 'Fogo de Chão Brazilian Steakhouse',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HCZ8ZI62X9INFxjwsQkwuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fogo-de-ch%C3%A3o-brazilian-steakhouse-chicago-4?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 1541,
#   'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.8942208218562,
#    'longitude': -87.6323306601503},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '661 N Lasalle Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['661 N Lasalle Blvd', 'Chicago, IL 60654']},
#   'phone': '+13129329330',
#   'display_phone': '(312) 932-9330',
#   'distance': 3952.1346138276876},
#  {'id': 'JZxTdRGnRFQbEbiz_P50sg',
#   'alias': 'michael-jordans-steak-house-chicago-2',
#   'name': "Michael Jordan's Steak House",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4fo_rwX1F5ZGKvZz1rS_kg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/michael-jordans-steak-house-chicago-2?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 916,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8912043, 'longitude': -87.6239424},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '505 N Michigan Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['505 N Michigan Ave', 'Chicago, IL 60611']},
#   'phone': '+13123218823',
#   'display_phone': '(312) 321-8823',
#   'distance': 4717.734297023891},
#  {'id': 'JMWtBuuNmTXqoBs06Wt_7w',
#   'alias': 'rpm-steak-chicago-2',
#   'name': 'RPM Steak',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4c66SdOFmArIvhTQz7H7kA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rpm-steak-chicago-2?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 1234,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8894143124861,
#    'longitude': -87.6305293460327},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$$',
#   'location': {'address1': '66 W Kinzie St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['66 W Kinzie St', 'Chicago, IL 60654']},
#   'phone': '+13122844990',
#   'display_phone': '(312) 284-4990',
#   'distance': 4283.657053561388},
#  {'id': '2WoMT3wSpp9vxZeTv6u-cw',
#   'alias': 'las-tablas-colombian-steakhouse-chicago',
#   'name': 'Las Tablas Colombian Steakhouse',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/j7ebljiWDdWZFtGF6CFTlg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/las-tablas-colombian-steakhouse-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 904,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'colombian', 'title': 'Colombian'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.935258, 'longitude': -87.662681},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2942 N Lincoln Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60657',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2942 N Lincoln Ave', 'Chicago, IL 60657']},
#   'phone': '+17738712414',
#   'display_phone': '(773) 871-2414',
#   'distance': 3571.9376280325187},
#  {'id': 'CQ75CQSyrsmb-S3UAwCHpw',
#   'alias': 'wildfire-chicago',
#   'name': 'Wildfire',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TT9dYc7NJuc-sp2anPUNKg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wildfire-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 1018,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8938172904842,
#    'longitude': -87.6333183422685},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '159 W Erie St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['159 W Erie St', 'Chicago, IL 60654']},
#   'phone': '+13127879000',
#   'display_phone': '(312) 787-9000',
#   'distance': 3888.7697806844494},
#  {'id': 'Qpev7myTY-SqxZh3sM56ag',
#   'alias': 'booth-one-chicago',
#   'name': 'Booth One',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iWXzXtn426cmtLmsHYc5WQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/booth-one-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 111,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.90594, 'longitude': -87.62835},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '1301 N State Pkwy',
#    'address2': None,
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60610',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1301 N State Pkwy', 'Chicago, IL 60610']},
#   'phone': '+13126490535',
#   'display_phone': '(312) 649-0535',
#   'distance': 4080.5586179735697},
#  {'id': 'fFX6L_QDexlgoYoCigJyPw',
#   'alias': 'canton-regio-chicago-4',
#   'name': 'Canton Regio',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gsxguA27ItJ-PBseYfVgXg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/canton-regio-chicago-4?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 431,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.858017, 'longitude': -87.6642617},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1510 W 18th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60608',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1510 W 18th St', 'Chicago, IL 60608']},
#   'phone': '+13127333045',
#   'display_phone': '(312) 733-3045',
#   'distance': 5359.848754948452},
#  {'id': 'Pcg4FtfbvSMMwrYuE1yVjQ',
#   'alias': 'mastros-steakhouse-chicago',
#   'name': "Mastro's Steakhouse",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eJgg2DXs7C6JwmaOdYQ9TQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mastros-steakhouse-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 1178,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8914200867251,
#    'longitude': -87.6299571990967},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '520 N Dearborn St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['520 N Dearborn St', 'Chicago, IL 60654']},
#   'phone': '+13125215100',
#   'display_phone': '(312) 521-5100',
#   'distance': 4241.525259201574},
#  {'id': 'H3KB1EigcCQU9sbQCi-6kg',
#   'alias': 'mon-ami-gabi-chicago',
#   'name': 'Mon Ami Gabi',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XoajxU2hNqe0AIDfyAkIBQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mon-ami-gabi-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 686,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'modern_european', 'title': 'Modern European'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.924093, 'longitude': -87.636974},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '2300 N Lincoln Park W',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60614',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2300 N Lincoln Park W', 'Chicago, IL 60614']},
#   'phone': '+17733488886',
#   'display_phone': '(773) 348-8886',
#   'distance': 3978.0128355761417},
#  {'id': 'uyUKtGWLYgu-RLjlNImy0A',
#   'alias': 'tango-sur-chicago',
#   'name': 'Tango Sur',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EiI7sh3K5jpB9dWCTPwwbg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tango-sur-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 2210,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'argentine', 'title': 'Argentine'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.9507843879442,
#    'longitude': -87.6639031774259},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3763 N Southport Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60613',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['3763 N Southport Ave', 'Chicago, IL 60613']},
#   'phone': '+17734775466',
#   'display_phone': '(773) 477-5466',
#   'distance': 5201.26553008441},
#  {'id': 'LU-NBsbLAwvzKlopsVeB7w',
#   'alias': 'weber-grill-restaurant-chicago',
#   'name': 'Weber Grill Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cdplklEtMcZZsA--JZMEHw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/weber-grill-restaurant-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 1415,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.8918845, 'longitude': -87.6278923},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '539 N State St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['539 N State St', 'Chicago, IL 60654']},
#   'phone': '+13124679696',
#   'display_phone': '(312) 467-9696',
#   'distance': 4380.36300827697},
#  {'id': 'olT3-oFfj5jCuv49M6gZgQ',
#   'alias': 'chicago-cut-steakhouse-chicago',
#   'name': 'Chicago Cut Steakhouse',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2ec80E8WBXrZHfZv0CGLtw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chicago-cut-steakhouse-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 1440,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8879719146942,
#    'longitude': -87.6333480203605},
#   'transactions': ['pickup'],
#   'price': '$$$$',
#   'location': {'address1': '300 N Lasalle',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['300 N Lasalle', 'Chicago, IL 60654']},
#   'phone': '+13123291800',
#   'display_phone': '(312) 329-1800',
#   'distance': 4143.383388864527},
#  {'id': 'fKdjKetxIAUJ9hv8MnzVpQ',
#   'alias': 'trulucks-chicago-2',
#   'name': "Truluck's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7kbmYw3c50_3-VvhrwXclw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/trulucks-chicago-2?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 149,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8981951, 'longitude': -87.6266769},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '41 E Chestnut St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['41 E Chestnut St', 'Chicago, IL 60611']},
#   'phone': '+13129820050',
#   'display_phone': '(312) 982-0050',
#   'distance': 4304.3435867143835},
#  {'id': 'XsGNjQODQGHMUPKrS_xEnA',
#   'alias': 'the-capital-grille-chicago-3',
#   'name': 'The Capital Grille',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q-WFuf42pmkkxu6m2x7R-Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-capital-grille-chicago-3?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 740,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.893789, 'longitude': -87.622358},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '633 N Saint Clair St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['633 N Saint Clair St', 'Chicago, IL 60611']},
#   'phone': '+13123379400',
#   'display_phone': '(312) 337-9400',
#   'distance': 4756.808448551692},
#  {'id': 'sKXmrjavCIF0CYb9YlAg_A',
#   'alias': 'gt-prime-steakhouse-chicago',
#   'name': 'GT Prime Steakhouse',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UtGkEv6ppa0jkTkGkbTSag/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gt-prime-steakhouse-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 227,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.895123, 'longitude': -87.633846},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '707 North Wells St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['707 North Wells St', 'Chicago, IL 60654']},
#   'phone': '+13126006305',
#   'display_phone': '(312) 600-6305',
#   'distance': 3808.1925895963923},
#  {'id': 'd6UbRb9W5eA1yL-DuVZ8ug',
#   'alias': 'zed451-chicago',
#   'name': 'ZED451',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/I2dloQ4kf9Gj9E8U0unmlg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zed451-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 1307,
#   'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'lounges', 'title': 'Lounges'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.896111, 'longitude': -87.63102},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '739 N Clark St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['739 N Clark St', 'Chicago, IL 60654']},
#   'phone': '+13122666691',
#   'display_phone': '(312) 266-6691',
#   'distance': 3997.423327339482},
#  {'id': 'VikWqZa32i70Qp-ETzw_lw',
#   'alias': 'hugos-frog-bar-and-fish-house-chicago',
#   'name': "Hugo's Frog Bar & Fish House",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RDkr0mVWCDT0Z4Oe2iDmUw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hugos-frog-bar-and-fish-house-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 915,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.901191, 'longitude': -87.627793},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '1024 North Rush',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1024 North Rush', 'Chicago, IL 60611']},
#   'phone': '+13126400999',
#   'display_phone': '(312) 640-0999',
#   'distance': 4159.119580566803},
#  {'id': '_mvEpTQ7IuUs51cWXfzGKA',
#   'alias': 'tavern-on-rush-chicago',
#   'name': 'Tavern On Rush',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/r0miaeulPvtQtH1p31AEVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tavern-on-rush-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 917,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.9018219998443,
#    'longitude': -87.6279733472541},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '1031 N Rush St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1031 N Rush St', 'Chicago, IL 60611']},
#   'phone': '+13126649600',
#   'display_phone': '(312) 664-9600',
#   'distance': 4137.376143386627},
#  {'id': '8wARj6QqmnSkUqLwoBCn7w',
#   'alias': 'gibsons-italia-chicago-2',
#   'name': 'Gibsons Italia',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rDso5nJU4VEc3at64sN2Iw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gibsons-italia-chicago-2?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 243,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8866045, 'longitude': -87.6396918},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '233 N Canal St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60606',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['233 N Canal St', 'Chicago, IL 60606']},
#   'phone': '+13124141100',
#   'display_phone': '(312) 414-1100',
#   'distance': 3800.9444930275968},
#  {'id': 'XCdk3YPa98n16uHU6IauJA',
#   'alias': 'texas-de-brazil-chicago-3',
#   'name': 'Texas de Brazil',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MLea4fW9UJcZXI1Bt4liNA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/texas-de-brazil-chicago-3?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 189,
#   'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.891161, 'longitude': -87.622115},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '210 E Upper Illinois St',
#    'address2': '',
#    'address3': 'Optima Chicago Ctr',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['210 E Upper Illinois St',
#     'Optima Chicago Ctr',
#     'Chicago, IL 60611']},
#   'phone': '+13125950913',
#   'display_phone': '(312) 595-0913',
#   'distance': 4861.817010356638},
#  {'id': 'wUkLiVC0XDuRs9zihWUPTw',
#   'alias': 'ditkas-restaurant-chicago',
#   'name': "Ditka's Restaurant",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ShAUQ83xgLsCczCSakrsPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ditkas-restaurant-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 906,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.89859, 'longitude': -87.62558},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '100 E Chestnut St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['100 E Chestnut St', 'Chicago, IL 60611']},
#   'phone': '+13125878989',
#   'display_phone': '(312) 587-8989',
#   'distance': 4379.168576974348},
#  {'id': 'Q3SMNxfKtVhEwt4d7S_8vw',
#   'alias': 'rosebud-on-rush-chicago-2',
#   'name': 'Rosebud on Rush',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/a2RuVH7hL_3MS0VoMWQo2A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rosebud-on-rush-chicago-2?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 790,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.895633, 'longitude': -87.62571},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '720 N Rush St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['720 N Rush St', 'Chicago, IL 60611']},
#   'phone': '+13122666444',
#   'display_phone': '(312) 266-6444',
#   'distance': 4436.533812071599},
#  {'id': 'rgHFY55p10VVur7N3s-z5Q',
#   'alias': 'roka-akor-chicago-chicago',
#   'name': 'Roka Akor - Chicago',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5Y6wK7K_U7e0_mYawKbtpQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/roka-akor-chicago-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 1082,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8905877769375,
#    'longitude': -87.6312957381504},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '456 N Clark St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['456 N Clark St', 'Chicago, IL 60654']},
#   'phone': '+13124777652',
#   'display_phone': '(312) 477-7652',
#   'distance': 4173.442923580503},
#  {'id': 'E974TODU6F-HCzUS02nXiQ',
#   'alias': 'tortoise-supper-club-chicago-2',
#   'name': 'Tortoise Supper Club',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Hw9cYVJggOKRggoLMTXygw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tortoise-supper-club-chicago-2?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 451,
#   'categories': [{'alias': 'supperclubs', 'title': 'Supper Clubs'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8887554967998,
#    'longitude': -87.6282440151018},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '350 N State St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60654',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['350 N State St', 'Chicago, IL 60654']},
#   'phone': '+13127551700',
#   'display_phone': '(312) 755-1700',
#   'distance': 4486.26002114934},
#  {'id': 'mMnW530e_S5_7oV2HJWDpw',
#   'alias': 'lawrys-the-prime-rib-chicago-2',
#   'name': "Lawry's The Prime Rib",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_LBoMSZYVeUH9wgqjCC2tQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lawrys-the-prime-rib-chicago-2?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 737,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.893461, 'longitude': -87.625029},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '100 E Ontario St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['100 E Ontario St', 'Chicago, IL 60611']},
#   'phone': '+13127875000',
#   'display_phone': '(312) 787-5000',
#   'distance': 4554.369638610989},
#  {'id': 'ISK4YPxKYvG9PzmxBE6CJg',
#   'alias': 'bistronomic-chicago',
#   'name': 'Bistronomic',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_qdgX3UcCIFjq2ZQW2SWcQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bistronomic-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 527,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'french', 'title': 'French'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8979072566376,
#    'longitude': -87.6272430870994},
#   'transactions': ['pickup'],
#   'price': '$$$',
#   'location': {'address1': '840 N Wabash Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['840 N Wabash Ave', 'Chicago, IL 60611']},
#   'phone': '+13129448400',
#   'display_phone': '(312) 944-8400',
#   'distance': 4258.313246178805},
#  {'id': 'Q0oO6sTrUoSqeiJHIGaLaw',
#   'alias': 'eddie-vs-prime-seafood-and-steaks-chicago',
#   'name': "Eddie V's Prime Seafood and Steaks",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/e1Lr3L98NWHEI8jK_q9K8g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/eddie-vs-prime-seafood-and-steaks-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 611,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'lounges', 'title': 'Lounges'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.891544320187, 'longitude': -87.6252151962952},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '521 N Rush St',
#    'address2': 'Ste R01',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['521 N Rush St', 'Ste R01', 'Chicago, IL 60611']},
#   'phone': '+13125951114',
#   'display_phone': '(312) 595-1114',
#   'distance': 4605.262954227963},
#  {'id': 'f1neY8Zd9xld7BB7G7mC0Q',
#   'alias': 'steak-48-chicago',
#   'name': 'Steak 48',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QyW-NPOVE8t-lJ6pmyQvgw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/steak-48-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 440,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.893, 'longitude': -87.62637},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '615 N Wabash Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['615 N Wabash Ave', 'Chicago, IL 60611']},
#   'phone': '+13122664848',
#   'display_phone': '(312) 266-4848',
#   'distance': 4456.054488956836},
#  {'id': 'g7GcOkQSOfC9JONw_rkNwQ',
#   'alias': 'carmines-chicago',
#   'name': "Carmine's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T8BRpX_2kEU6Y0gM_6GDnQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/carmines-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 808,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.9019953, 'longitude': -87.6281131},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '1043 N Rush St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1043 N Rush St', 'Chicago, IL 60611']},
#   'phone': '+13129887676',
#   'display_phone': '(312) 988-7676',
#   'distance': 4124.163004884799},
#  {'id': 'AHpwEeyDT_brMzF5cYQpag',
#   'alias': 'rl-restaurant-chicago',
#   'name': 'RL Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MA7W-5eGDnHEsbY9jigpNg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rl-restaurant-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 693,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.897007, 'longitude': -87.624961},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '115 E Chicago Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['115 E Chicago Ave', 'Chicago, IL 60611']},
#   'phone': '+13124751100',
#   'display_phone': '(312) 475-1100',
#   'distance': 4463.189614111665},
#  {'id': 'KFNk35nSCX8IRum2aJdRag',
#   'alias': 'el-nandu-restaurant-chicago',
#   'name': 'El Nandu Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/STXtoua-nVP6d2puZlLATg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-nandu-restaurant-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 336,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'argentine', 'title': 'Argentine'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.92452, 'longitude': -87.6962099},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2731 W Fullerton Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60647',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2731 W Fullerton Ave', 'Chicago, IL 60647']},
#   'phone': '+17732780900',
#   'display_phone': '(773) 278-0900',
#   'distance': 2648.081613063601},
#  {'id': 'oT7oYmyGKFdBk0IkuNZG0A',
#   'alias': 'mity-nice-chicago-15',
#   'name': 'Mity Nice',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UiOxfob0oK08yWPXSWhUKw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mity-nice-chicago-15?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 411,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8981170141684,
#    'longitude': -87.6232167949677},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '835 N Michigan Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['835 N Michigan Ave', 'Chicago, IL 60611']},
#   'phone': '+13123354745',
#   'display_phone': '(312) 335-4745',
#   'distance': 4581.889482895465},
#  {'id': 'doMpF2X9a2F8WoQH78ZL4w',
#   'alias': 'iii-forks-chicago-2',
#   'name': 'III Forks',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1FYmQxZdMg1NVar522kMVw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/iii-forks-chicago-2?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 405,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.88651, 'longitude': -87.61743},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '180 N Field Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60601',
# ...
#   'rating': 4.0,
#   'coordinates': {'latitude': 42.00402, 'longitude': -87.74776},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '6755 N Cicero Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Lincolnwood',
#    'zip_code': '60712',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['6755 N Cicero Ave', 'Lincolnwood, IL 60712']},
#   'phone': '+18476966755',
#   'display_phone': '(847) 696-6755',
#   'distance': 12421.920735545667},
#  {'id': 'i2LY-w3dNW5Zzcm4w6XHPQ',
#   'alias': 'rosebud-prime-chicago',
#   'name': 'Rosebud Prime',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V6NiVOthqUus7iPDVj_dwg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rosebud-prime-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 336,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.881632, 'longitude': -87.629018},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '1 S Dearborn St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60603',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1 S Dearborn St', 'Chicago, IL 60603']},
#   'phone': '+13123841900',
#   'display_phone': '(312) 384-1900',
#   'distance': 4808.774801681534},
#  {'id': 'Ky6VeoI1-0M0Z46v5gSWwg',
#   'alias': 'the-steak-out-chicago',
#   'name': 'The Steak Out',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zGEwxKRxR8XhFYeT1lnpgw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-steak-out-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 14,
#   'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.85365, 'longitude': -87.62675},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '2113 S State St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60616',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2113 S State St', 'Chicago, IL 60616']},
#   'phone': '+13122852890',
#   'display_phone': '(312) 285-2890',
#   'distance': 7114.075745468025},
#  {'id': 'bu-QcR2BO9vfAUeGx9a3ow',
#   'alias': 'frans-beef-chicago',
#   'name': "Fran's Beef",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Pay9PkW57pyTvf-beMXb3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/frans-beef-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 12,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.85438, 'longitude': -87.66383},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2021 S Blue Island Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60608',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2021 S Blue Island Ave', 'Chicago, IL 60608']},
#   'phone': '+13124218188',
#   'display_phone': '(312) 421-8188',
#   'distance': 5762.64701351569},
#  {'id': 'epOvUIFJEm9rdlxwA1jV8A',
#   'alias': 'sabor-a-café-colombian-steakhouse-chicago-4',
#   'name': 'Sabor A Café Colombian Steakhouse',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/twisjjdvPYQn3KXtuj-0Mw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sabor-a-caf%C3%A9-colombian-steakhouse-chicago-4?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 208,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'colombian', 'title': 'Colombian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.990297, 'longitude': -87.691057},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2435 W Peterson Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60659',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2435 W Peterson Ave', 'Chicago, IL 60659']},
#   'phone': '+17738786327',
#   'display_phone': '(773) 878-6327',
#   'distance': 9530.484317555656},
#  {'id': 'FsaYqqX1QlWYR1MTYf_kzQ',
#   'alias': 'las-tablas-chicago-2',
#   'name': 'Las Tablas',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6ObHKJRyLzEFW5amJTxDJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/las-tablas-chicago-2?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 357,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 41.95373, 'longitude': -87.750767},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4920 W Irving Park Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60641',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['4920 W Irving Park Rd', 'Chicago, IL 60641']},
#   'phone': '+17732020999',
#   'display_phone': '(773) 202-0999',
#   'distance': 8101.843083104154},
#  {'id': 'ceTrCRZ1Ah1xhzJkLPBYVw',
#   'alias': 'select-cut-steak-house-chicago',
#   'name': 'Select Cut Steak House',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vE-od-Qu5O0-BWNaj-RrLQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/select-cut-steak-house-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 209,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.932973, 'longitude': -87.649073},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '2808 N Halsted St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60657',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2808 N Halsted St', 'Chicago, IL 60657']},
#   'phone': '+17732441500',
#   'display_phone': '(773) 244-1500',
#   'distance': 3898.7983519969066},
#  {'id': 'GmrV23gxkB3B5gVbvdRMJQ',
#   'alias': 'babas-famous-steak-and-lemonade-chicago-9',
#   'name': 'Babas Famous Steak & Lemonade',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_6MsBjsC3KFc62fi78JmBg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/babas-famous-steak-and-lemonade-chicago-9?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 3,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 1.0,
#   'coordinates': {'latitude': 41.8798969, 'longitude': -87.7245996},
#   'transactions': [],
#   'location': {'address1': '3958 W Monroe St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60624',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['3958 W Monroe St', 'Chicago, IL 60624']},
#   'phone': '+17732651111',
#   'display_phone': '(773) 265-1111',
#   'distance': 4824.435221340931},
#  {'id': 'fhaRGmrgFep8_uQt1p4ALA',
#   'alias': 'el-llano-restaurant-chicago-3',
#   'name': 'El Llano Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9OK4GdZLXStacAzWcdtfsw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-llano-restaurant-chicago-3?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 59,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'colombian', 'title': 'Colombian'},
#    {'alias': 'empanadas', 'title': 'Empanadas'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.954179, 'longitude': -87.719454},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '4011 N Elston Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60618',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['4011 N Elston Ave', 'Chicago, IL 60618']},
#   'phone': '+17738669500',
#   'display_phone': '(773) 866-9500',
#   'distance': 6450.14361660878},
#  {'id': '2-MNbRnfha4fC3-amMVIpA',
#   'alias': 'kevins-hamburger-heaven-chicago',
#   'name': "Kevin's Hamburger Heaven",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/j4cfA-pAkJ26YG0z-nOc9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kevins-hamburger-heaven-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 40,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 41.823861, 'longitude': -87.64026},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '554 W Pershing Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60609',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['554 W Pershing Rd', 'Chicago, IL 60609']},
#   'phone': '+17739245771',
#   'display_phone': '(773) 924-5771',
#   'distance': 9558.574267874263},
#  {'id': '3uKYAB16BWMQVh6607hbcQ',
#   'alias': 'shallots-bistro-skokie',
#   'name': 'Shallots Bistro',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XSVW_xYdHlxUnnz_zNcUog/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shallots-bistro-skokie?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 74,
#   'categories': [{'alias': 'kosher', 'title': 'Kosher'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 42.009021, 'longitude': -87.762529},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'price': '$$$$',
#   'location': {'address1': '7016 Carpenter Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Skokie',
#    'zip_code': '60077',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['7016 Carpenter Rd', 'Skokie, IL 60077']},
#   'phone': '+18476773463',
#   'display_phone': '(847) 677-3463',
#   'distance': 13509.414412190561},
#  {'id': 'BbAPGoGHCNXsg3PnZK0nfw',
#   'alias': 'mexico-steakhouse-chicago',
#   'name': 'Mexico Steakhouse',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-5zhuzKTqUPI_55k_wYwBA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mexico-steakhouse-chicago?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 63,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8401565551758,
#    'longitude': -87.6604309082031},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2983 S Archer Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60608',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2983 S Archer Ave', 'Chicago, IL 60608']},
#   'phone': '+17732545151',
#   'display_phone': '(773) 254-5151',
#   'distance': 7369.896758481705},
#  {'id': 'mR0pj7_iM_Noh7ZZMqSK4Q',
#   'alias': 'outback-steakhouse-skokie',
#   'name': 'Outback Steakhouse',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MPtDVmx4yOV8ff4CYN5Y3Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/outback-steakhouse-skokie?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 205,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 42.011805, 'longitude': -87.76714},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '5535 Touhy Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Skokie',
#    'zip_code': '60077',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['5535 Touhy Ave', 'Skokie, IL 60077']},
#   'phone': '+18476747411',
#   'display_phone': '(847) 674-7411',
#   'distance': 13972.768746937354},
#  {'id': 'oX7mCtpN8YJXk34NL_sDbQ',
#   'alias': 'iii-forks-chicago-3',
#   'name': 'III Forks',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/iii-forks-chicago-3?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 1,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 1.0,
#   'coordinates': {'latitude': 41.88525, 'longitude': -87.61846},
#   'transactions': [],
#   'location': {'address1': '333 E Benton Pl',
#    'address2': None,
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60601',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['333 E Benton Pl', 'Chicago, IL 60601']},
#   'phone': '+13129384303',
#   'display_phone': '(312) 938-4303',
#   'distance': 5382.114251686573},
#  {'id': 'djn_gwVaQ_u7LMbUy72CLA',
#   'alias': 'longhorn-steakhouse-skokie',
#   'name': 'LongHorn Steakhouse',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aKRybUlOICcFV-fuT4-8Ow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/longhorn-steakhouse-skokie?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 135,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 42.012312, 'longitude': -87.712177},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3300 W Touhy Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Skokie',
#    'zip_code': '60076',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['3300 W Touhy Ave', 'Skokie, IL 60076']},
#   'phone': '+18476741673',
#   'display_phone': '(847) 674-1673',
#   'distance': 12249.885652828354},
#  {'id': 'y5y_VIqVZ9IMDoNaeKsftg',
#   'alias': 'steak-n-egger-cicero-5',
#   'name': "Steak 'n Egger",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5ggNSzGIu5llFpVknhNqQw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/steak-n-egger-cicero-5?adjust_creative=eAOaimX85y-R9FkFMWxzPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eAOaimX85y-R9FkFMWxzPQ',
#   'review_count': 20,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 41.8653411865234,
#    'longitude': -87.7645645141602},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '5601 W Roosevelt Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Cicero',
#    'zip_code': '60804',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['5601 W Roosevelt Rd', 'Cicero, IL 60804']},
#   'phone': '+17086560888',
#   'display_phone': '(708) 656-0888',
#   'distance': 8449.66881409134}]

# %% [markdown]
# Step 2: Create a DataFrame from the list above.

# %%
chi_df = pd.DataFrame(chi_stk_list)

# %% [markdown]
# Step 3: drop all the colums we don't need.

# %%
chi_df.drop(['alias','distance', 'id', 'image_url', 'is_closed','location', 'transactions','categories', 'url'], axis = 'columns', inplace=True)

# %% [markdown]
# Step 4: Add a collumn to the dataframe with the specific food type

# %%
chi_df['category']='steak'

# %% [markdown]
# Step 5: Create a new collumn to convert number of $$ to an integer.

# %%
xxxxx

# %% [markdown]
# step 6: Create a mean of the Price collumn

# %% [markdown]
# Step 7: Add that mean to the rows with missing values

# %% [markdown]
# Step x: rearrange the collumns

# %%
chi_df = chi_df[['name','price','review_count','rating','coordinates']]

# %% [markdown]
# Step 9: Concat this clean DataFrame to the master DataFrame.

# %% [markdown]
# ### Population of matching 40km radius

# %%
pop = {'Portland':1907395, 
'Los Angeles':10055380, 
'New York City':13409590, 
'Boston':3342667, 
'Chicago':6377851, 
'Austin':1142575, 
'miami':3140501, 
'Oklahoma City':992543, 
'Minneapolis':2648228, 
'San Diego':2684215}

# %% [markdown]
# ### Longitude and Latitude of the center of the radius

# %%
start_point={'new york':(40.70544486444615, -73.99429321289062),
'chicago':(41.90515925618311, -87.67776489257812),
'portland':(45.515785397030584, -122.65411376953125),
'san francisco':(37.76089938976322, -122.43644714355469),
'los angeles':(34.0615895441259, -118.32138061523438),
'boston':(42.34784169448538, -71.07124328613281),
'austin':(30.305156315977833, -97.75772094726562),
'miami':(25.752753731496888, -80.2880859375),
'san diego':(32.790569394537286, -117.15408325195312),
'tulsa':(36.10220015729658, -95.9271240234375),
'minneapolis':(44.96558443188442, -93.2904052734375)}

# %%
{
    "city": row['location']['city'],
    'name': row['name']
    'phone_number': row['number'],
    'steak': 'steak' in row['categories'].....
}

# %%
#df[df['city']=='chicago']

# %% [markdown]
# two sample Z test -
